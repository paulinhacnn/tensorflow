# %% [markdown]
# # Exercise

# %% [markdown]
# #### import numpy, import pandas, import matplotlib and sklearn. Also set visualization to be shown inline in the notebook

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline

# %% [markdown]
# #### Set numpy`s Random Seed to 101

# %%
np.random.seed(101)

# %% [markdown]
# #### Create a Numpy Matrix of 100 rows by 5 columns consisting of random integers from 1-100. (Keep in mind that the upper limit may be exlusive.

# %%
nd = np.random.randint(1, 101,(100, 5))

# %%
nd
# Out:
# array([[ 94,  69,  54,   7,  68],
#        [ 25, 100,   1,  68,  94],
#        [ 48,  16,  73,  69,  61],
#        [ 92,  81,  84,  12,  45],
#        [  7,  59,  51,  35,  40],
#        [ 72,  27,  92,  60,  90],
#        [  1,  87,  15,  92,  48],
#        [ 75,  24,  43,  49,  27],
#        [  5,  67,  44,  85,  31],
#        [ 80,  10,  79,  50,  29],
#        [ 90,  35,  94,  42,  22],
#        [ 89,   3,  87,  85,  26],
#        [  3,  51,  50,  64,   3],
#        [ 96,  29,  22,  63,  51],
#        [100,  53,  57,   6,  43],
#        [ 83,  76,  23,  35,  49],
#        [ 61,  73,  10,  96,  97],
#        [ 47,  60,  52,  48,   5],
#        [ 60,  37,  35,  99,  82],
#        [  9,  96,  61,  47,  20],
#        [ 14,  36,  15,   7,  25],
#        [ 32,  10,  32,  13,  49],
#        [ 76,  26,  86,  63,  22],
#        [ 78,  69,  20,  67,  71],
#        [ 74,  50,  28,  36,  34],
#        [ 43,  34,  94,  40,  65],
#        [  2,  59,  18,  60,  72],
# ...

# %% [markdown]
# #### Create a 2-D visualization using plt.show of the numpy matrix with a colorbar.Add a title to your plot.Bonus: Figure out how to change the aspect of the inshow() plot.

# %%
plt.imshow(nd, aspect=0.03)
plt.colorbar()
plt.xlim(0, 4)
plt.ylim(0, 100)
plt.title('My dados')
# Out:
# Text(0.5,1,'My dados')

# %%
dados = np.random.randint(1, 101, (50, 5))

# %%
dados
# Out:
# array([[  5,  83,  60,  55,  80],
#        [ 58,  42,  41,  31,  48],
#        [  3,  75,   1,  47,  70],
#        [ 44,  76, 100,  25,  17],
#        [ 72,  27,  18,  13,  25],
#        [ 45,  27,  90,  71,  33],
#        [  3,  47,  75,  17,  53],
#        [ 88,  40,  97,  29,  81],
#        [ 61,  86,  89,  12,   2],
#        [ 76,  93,  10,  11,  48],
#        [ 36,  69,  32,  22,  74],
#        [ 73,  29,   8,  19,  78],
#        [ 90,  53,  50,  21,  40],
#        [ 11,  63,  42,  69,  35],
#        [ 24,  11,  99,  17,   2],
#        [ 97,  42,  21,  13,  71],
#        [ 13,  98,  34,  35,  98],
#        [ 11,  28,  52,  87,  83],
#        [ 62,  83,  42,  74,  83],
#        [ 11,  90,  94,  36,   2],
#        [ 31,  98,  70,  77,  51],
#        [ 56,  63,  89,  81,   2],
#        [  5,  29,  40,  92,  62],
#        [ 16,  89,  27,  93,  59],
#        [ 97,   5,   5,  71,  86],
#        [ 24,  39,   6,  70,  24],
#        [ 37,  23,  18,   6,  65],
# ...

# %%
df = pd.DataFrame(data=dados, columns=['f1', 'f2', 'f3', 'label'])

# %%
df
# Out:
#     f1  f2   f3  label
# 0   20  10   33     93
# 1   90  16   83      5
# 2   76  65    4     90
# 3   14  41   10     18
# 4   28  60   16     37
# 5   30  88   82     42
# 6   88  95   97     12
# 7   34  94   81     49
# 8    5  49   50     46
# 9   44  84   22     28
# 10  64  14   22     41
# 11  55  32   82     44
# 12  64  54   48     52
# 13  92  60   14     61
# 14  47   4   36     91
# 15  69  59   44     20
# 16  18  28   78     35
# 17  21  10   31     41
# 18  60  89   93     91
# 19  27  73   40     46
# 20  24  38   41     11
# 21  12  85   24      7
# 22  25  19   38     25
# 23  81  25   26      6
# 24  68  99   79     31
# 25  37  53   17     72
# 26  85  28   40     21
# 27  46  20   15     23
# 28  98  68   77     74
# 29  86  60   39     72
# 30  13  78    3      7
# 31  39  25   28     55
# 32  50  69   24     75
# 33  42  82   72     25
# 34  64  53   82     26
# 35  57   8   42     17
# 36  43  12   26     22
# 37  75   7   26     21
# 38  64  61   90     69
# ...

# %%
df.plot(x='f1', y='f2', kind='scatter')

# %%
scaler = MinMaxScaler()

# %%
result = scaler.fit_transform(df)

# %%
result
# Out:
# array([[ 0.16129032,  0.06315789,  0.30927835,  1.        ],
#        [ 0.91397849,  0.12631579,  0.82474227,  0.        ],
#        [ 0.76344086,  0.64210526,  0.01030928,  0.96590909],
#        [ 0.09677419,  0.38947368,  0.07216495,  0.14772727],
#        [ 0.24731183,  0.58947368,  0.13402062,  0.36363636],
#        [ 0.2688172 ,  0.88421053,  0.81443299,  0.42045455],
#        [ 0.89247312,  0.95789474,  0.96907216,  0.07954545],
#        [ 0.31182796,  0.94736842,  0.80412371,  0.5       ],
#        [ 0.        ,  0.47368421,  0.48453608,  0.46590909],
#        [ 0.41935484,  0.84210526,  0.19587629,  0.26136364],
#        [ 0.6344086 ,  0.10526316,  0.19587629,  0.40909091],
#        [ 0.53763441,  0.29473684,  0.81443299,  0.44318182],
#        [ 0.6344086 ,  0.52631579,  0.46391753,  0.53409091],
#        [ 0.93548387,  0.58947368,  0.11340206,  0.63636364],
#        [ 0.4516129 ,  0.        ,  0.34020619,  0.97727273],
# ...

# %%
df.head()
# Out:
#    f1  f2  f3  label
# 0  20  10  33     93
# 1  90  16  83      5
# 2  76  65   4     90
# 3  14  41  10     18
# 4  28  60  16     37

# %%
x = df[['f1', 'f2', 'f3']]

# %%
y = df['label']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=101)

# %%
x_train.shape
# Out:
# (35, 3)

# %%
x_test.shape
# Out:
# (15, 3)

# %%
x_train
# Out:
#     f1  f2  f3
# 3   14  41  10
# 41  65  83  52
# 30  13  78   3
# 15  69  59  44
# 20  24  38  41
# 43  80  85  30
# 38  64  61  90
# 44  84  72  35
# 39  89  40  76
# 10  64  14  22
# 49  89  61  97
# 25  37  53  17
# 33  42  82  72
# 36  43  12  26
# 2   76  65   4
# 27  46  20  15
# 34  64  53  82
# 35  57   8  42
# 8    5  49  50
# 19  27  73  40
# 29  86  60  39
# 12  64  54  48
# 5   30  88  82
# 0   20  10  33
# 28  98  68  77
# 4   28  60  16
# 40  60  38  17
# 13  92  60  14
# 9   44  84  22
# 48  13  55  50
# 23  81  25  26
# 6   88  95  97
# 17  21  10  31
# 11  55  32  82
# 31  39  25  28

# %%
y_train
# Out:
# 3     18
# 41    12
# 30     7
# 15    20
# 20    11
# 43    37
# 38    69
# 44    38
# 39    78
# 10    41
# 49    57
# 25    72
# 33    25
# 36    22
# 2     90
# 27    23
# 34    26
# 35    17
# 8     46
# 19    46
# 29    72
# 12    52
# 5     42
# 0     93
# 28    74
# 4     37
# 40    83
# 13    61
# 9     28
# 48    19
# 23     6
# 6     12
# 17    41
# 11    44
# 31    55
# Name: label, dtype: int64

# %%
y_train.shape
# Out:
# (35,)

# %% [markdown]
# # GREAT JOB
